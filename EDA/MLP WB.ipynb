# %%
import numpy as np
import pandas as pd
# %matplotlib inline 

housing = pd.read_csv('./data/Ames_Housing_Price_Data.csv', index_col=0)
housing.shape
# Out:
# (2580, 81)

# %% [markdown]
# The below correlation Matrix shows the relationships with all variables

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(housing.corr(), fignum=f.number)
plt.xticks(range(housing.select_dtypes(['number']).shape[1]), housing.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(housing.select_dtypes(['number']).shape[1]), housing.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %% [markdown]
# There is an outlier with the dot for a nearly 5000 square foot house below 200K

# %%
import numpy
plt.scatter(price,liv, color = "red")
plt.xlabel("Price")
plt.ylabel('Living Area Sqft')
# Out:
# Text(0, 0.5, 'Living Area Sqft')

# %% [markdown]
# Below graph indicates that a Quality ranking of 5 is represented across the spectrum of price per square foot. Interestingly, a score above 5 seems to have little or no impact on price per square foot, whereas a score below 5 has a significant impact on price per square foot.

# %%
PricePer=housing["SalePrice"]/housing["GrLivArea"]
condition=housing["OverallCond"]
plt.scatter(PricePer,condition, color = "red")
plt.xlabel("Price Per")
plt.ylabel('Overall Condition')
# Out:
# Text(0, 0.5, 'Overall Condition')

# %%
PricePer=housing["SalePrice"]/housing["GrLivArea"]
qual=housing["OverallQual"]
plt.scatter(PricePer,qual, color = "red")
plt.xlabel("Price Per")
plt.ylabel('Qual')
# Out:
# Text(0, 0.5, 'Qual')

# %% [markdown]
# Price per sqare foot has a wide range as demonstrated below

# %%
PricePer.sort_values()
# Out:
# 428     15.371394
# 741     30.372058
# 206     33.692722
# 389     38.510911
# 310     39.510265
#           ...
# 74     237.590799
# 66     248.987854
# 616    253.031223
# 585    258.738156
# 618    276.250881
# Length: 2580, dtype: float64
